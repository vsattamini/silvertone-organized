# %%
# Data manipulation
import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = 30
import math

# Data Visualiation
import matplotlib.pyplot as plt
import seaborn as sns

# System
import os

# Deep Learning
import tensorflow as tf

# %%
# Load Data
df = pd.read_csv('data/database_final.csv')

# %%
# Drop useless columns
df = df.drop(columns='Unnamed: 0')

# %%
df.columns
# Out:
# Index(['id', 'wave', 'spec', 'spectral_centroid', 'mfcc', 'chroma_stft',
#        'tonnetz', 'emotion', 'intensity', 'repetition', 'actor_gender',
#        'actor_age', 'source'],
#       dtype='object')

# %%
df['emotion'].nunique()
# Out:
# 17

# %%
df.groupby('emotion').count()
# Out:
#              id  wave  spec  spectral_centroid  mfcc  chroma_stft  tonnetz  \
# emotion
# 1            96    96    96                 96    96           96       96
# 2           192   192   192                192   192          192      192
# 3           192   192   192                192   192          192      192
# 4           192   192   192                192   192          192      192
# 5           192   192   192                192   192          192      192
# 6           192   192   192                192   192          192      192
# 7           192   192   192                192   192          192      192
# 8           192   192   192                192   192          192      192
# _SA           1     1     1                  1     1            1        1
# angry      1791  1791  1791               1791  1791         1791     1791
# disgust    1731  1731  1731               1731  1731         1731     1731
# fearful    1731  1731  1731               1731  1731         1731     1731
# happy      1731  1731  1731               1731  1731         1731     1731
# neutral    1607  1607  1607               1607  1607         1607     1607
# sad        1470  1470  1470               1470  1470         1470     1470
# surprised   400   400   400                400   400          400      400
# u            60    60    60                 60    60           60       60
#
#            intensity  repetition  actor_gender  actor_age  source
# emotion
# 1                 96          96            96         96      96
# 2                192         192           192        192     192
# 3                192         192           192        192     192
# 4                192         192           192        192     192
# 5                192         192           192        192     192
# 6                192         192           192        192     192
# 7                192         192           192        192     192
# 8                192         192           192        192     192
# _SA                1           1             1          1       1
# angry           1791        1791          1791       1791    1791
# disgust         1731        1731          1731       1731    1731
# fearful         1731        1731          1731       1731    1731
# happy           1731        1731          1731       1731    1731
# neutral         1607        1607          1607       1607    1607
# sad             1470        1470          1470       1470    1470
# surprised        400         400           400        400     400
# u                 60          60            60         60      60
