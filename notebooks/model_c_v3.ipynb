# %% [markdown]
# # Model

# %%
# Data manipulation
import numpy as np
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = 30
import math

# Data Visualiation
import matplotlib.pyplot as plt
import seaborn as sns

# System
import os

# Deep Learning
import tensorflow as tf
# Out:
# 2022-11-23 19:45:46.228928: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-23 19:45:48.130749: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-23 19:45:48.130791: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-23 19:45:51.038043: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-23 19:45:51.039514: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-23 19:45:51.039535: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# Load Data
df = pd.read_csv('data/database_final.csv')

# %%
df
# Out:
#        Unnamed: 0.1               id  \
# 0                 0           DC_a01
# 1                 1           DC_a03
# 2                 2           DC_a02
# 3                 3           DC_a05
# 4                 4           DC_a04
# ...             ...              ...
# 11957         11477  1006_IOM_FEA_XX
# 11958         11478  1006_ITS_ANG_XX
# 11959         11479  1006_IWL_DIS_XX
# 11960         11480  1006_ITS_DIS_XX
# 11961         11481  1006_IWL_SAD_XX
#
#                                                     wave  \
# 0      [0.03501127 0.05211012 0.0455472  ... 0.041400...
# 1      [0.02912198 0.04325936 0.03782155 ... 0.037337...
# 2      [0.02858488 0.04302428 0.03862399 ... 0.040070...
# 3      [0.01032823 0.01527868 0.01325043 ... 0.014167...
# 4      [0.02881919 0.04295465 0.03768336 ... 0.014060...
# ...                                                  ...
# 11957  [-0.00271055 -0.00441946 -0.00454724 ... -0.00...
# 11958  [-1.3573711e-04 -6.4209435e-04 -5.4852467e-04 ...
# 11959  [ 1.8942595e-03  1.8858456e-03  1.4217157e-03 ...
# 11960  [-0.00344728 -0.00468006 -0.00525419 ...  0.00...
# 11961  [-0.0021652  -0.00229028 -0.00179888 ...  0.  ...
#
#                                                     spec  \
# 0      [[-42.862747 -42.92587  -43.01268  ... -47.265...
# 1      [[-44.561855 -44.524857 -44.317585 ... -44.494...
# 2      [[-45.572945 -45.56851  -45.58338  ... -45.444...
# 3      [[-70.69988 -70.69988 -70.14702 ... -71.11232 ...
# 4      [[-54.48096  -54.554996 -54.34767  ... -72.017...
# ...                                                  ...
# 11957  [[-80.       -65.98134  -63.451202 ... -74.601...
# 11958  [[-63.750305 -68.83097  -75.43052  ... -80.   ...
# 11959  [[-78.81643  -74.11592  -67.58829  ... -79.457...
# 11960  [[-49.605522 -48.428017 -51.159893 ... -23.641...
# 11961  [[-40.86357  -45.568626 -56.56686  ... -52.476...
#
#                                        spectral_centroid  \
# 0      [[1.72759404e+00 1.11735368e+00 8.96038810e-01...
# 1      [[2.08022453e+00 1.67684091e+00 1.63161521e+00...
# 2      [[3.29410285e+00 2.95758198e+00 3.16878758e+00...
# 3      [[1.11756800e+01 1.24684918e+01 1.41911940e+01...
# 4      [[1.00821953e+00 4.75357226e-01 2.34976930e-01...
# ...                                                  ...
# 11957  [[ 628.31226224  549.12200565  533.00445015  5...
# 11958  [[ 318.53502015  474.67526569  625.84649942  6...
# 11959  [[ 622.40690525  576.12878333  568.44755916  6...
# 11960  [[ 637.17182856  662.42495326  661.05609333  6...
# 11961  [[ 443.12842371  442.10710719  496.81849755  5...
#
#                                                     mfcc  \
# 0      [-13.379193  -13.197718  -13.240178  -13.40585...
# 1      [-12.094262  -12.306206  -13.71257   -13.07329...
# 2      [-14.458181  -14.468512  -15.264155  -15.69551...
# 3      [-15.7304125 -13.741358  -13.427342  -14.36428...
# 4      [-11.881211  -12.674193  -13.911763  -15.31289...
# ...                                                  ...
# 11957  [[ 0.19856001  0.14082783  0.1321133  ...  0.2...
# 11958  [[ 0.06455994  0.06760315  0.14062564 ...  0.0...
# 11959  [[ 0.19957937  0.21638086  0.34762213 ...  0.0...
# 11960  [[ 0.2547052   0.20754212  0.21810158 ...  0.1...
# 11961  [[ 0.0996254   0.1054377   0.08276478 ...  0.1...
#
#                                              chroma_stft  \
# 0      [[0.96506786 0.98978186 1.         ... 1.     ...
# 1      [[0.9889284  0.9893815  0.98825294 ... 1.     ...
# 2      [[0.9867902  0.9820715  0.9909598  ... 0.97427...
# 3      [[0.8895628  0.8564363  0.9021018  ... 0.95775...
# 4      [[1.         0.99805677 0.9988299  ... 0.85910...
# ...                                                  ...
# 11957  [[0.09425195 0.20182107 0.6652878  ... 0.05394...
# 11958  [[1.         0.3741078  0.12400512 ... 0.51464...
# 11959  [[0.11185001 0.17461419 0.19080454 ... 0.26322...
# 11960  [[0.17107505 0.08638173 0.04173567 ... 0.48772...
# 11961  [[0.74121493 0.5531022  0.26172474 ... 0.56904...
#
#                                                  tonnetz  emotion  intensity  \
# 0      [[ 2.97094217e-02  2.75112048e-02  2.16223340e...    angry          0
# 1      [[ 3.15660209e-02  3.72062406e-02  5.44723706e...    angry          0
# 2      [[ 2.27529554e-02  3.45097151e-02  3.07241990e...    angry          0
# 3      [[ 6.51519219e-02  4.88883736e-02  3.62829911e...    angry          0
# 4      [[-1.40266694e-05 -4.07517343e-03 -1.45541046e...    angry          0
# ...                                                  ...      ...        ...
# 11957  [[ 3.61340625e-02  3.86059250e-02  3.75785498e...  fearful          0
# 11958  [[ 5.61954266e-02  4.05136305e-02  3.58292018e...    angry          0
# 11959  [[-2.83815877e-02 -1.44621438e-02  7.17421395e...  disgust          0
# 11960  [[ 3.07953713e-02  4.34058975e-02  6.71524114e...  disgust          0
# 11961  [[-1.38249975e-02  9.08432204e-03  4.54136795e...      sad          0
#
#        repetition actor_gender actor_age source  Unnamed: 0
# 0               0         male     young  savee         NaN
# 1               0         male     young  savee         NaN
# 2               0         male     young  savee         NaN
# 3               0         male     young  savee         NaN
# 4               0         male     young  savee         NaN
# ...           ...          ...       ...    ...         ...
# 11957           0       female       old  crema      7437.0
# 11958           0       female       old  crema      7438.0
# 11959           0       female       old  crema      7439.0
# 11960           0       female       old  crema      7440.0
# 11961           0       female       old  crema      7441.0
#
# [11962 rows x 15 columns]

# %%
df_short = df[df['source']=='ravdess']

# %%
# df_short = df

# %%
y = df_short['emotion']

# %%
df_short
# Out:
#       Unnamed: 0.1                    id  \
# 480              0  03-01-08-02-01-01-08
# 481              1  03-01-06-01-02-02-08
# 482              2  03-01-07-01-01-01-08
# 483              3  03-01-08-01-02-02-08
# 484              4  03-01-07-02-01-02-08
# ...            ...                   ...
# 1915          1435  03-01-07-01-02-01-08
# 1916          1436  03-01-06-02-02-01-08
# 1917          1437  03-01-08-01-01-02-08
# 1918          1438  03-01-08-01-02-01-08
# 1919          1439  03-01-07-02-02-01-08
#
#                                                    wave  \
# 480   [-9.79513861e-05 -1.53946385e-04 -1.14064045e-...
# 481   [-8.6506159e-05 -1.3339471e-04 -1.1452433e-04 ...
# 482   [ 4.4902441e-05  6.3644031e-05  3.8157756e-05 ...
# 483   [ 3.1838110e-05  4.1204537e-05  1.8614803e-05 ...
# 484   [-6.1997175e-06 -1.2222978e-05 -1.0545186e-05 ...
# ...                                                 ...
# 1915  [ 1.4008651e-04  2.0711741e-04  1.9653598e-04 ...
# 1916  [ 3.4688014e-06 -4.4427879e-06  6.5306676e-06 ...
# 1917  [ 1.26776829e-08 -1.92976639e-08  2.46308645e-...
# 1918  [ 2.04178959e-05  5.95841921e-05  2.21247574e-...
# 1919  [-3.7051029e-07  7.0713605e-07 -1.1072846e-06 ...
#
#                                                    spec  \
# 480   [[-80.       -80.       -80.       ... -40.051...
# 481   [[-80. -80. -80. ... -80. -80. -80.]\n [-80. -...
# 482   [[-80.       -80.       -80.       ... -80.   ...
# 483   [[-80. -80. -80. ... -80. -80. -80.]\n [-80. -...
# 484   [[-80. -80. -80. ... -80. -80. -80.]\n [-80. -...
# ...                                                 ...
# 1915  [[-80. -80. -80. ... -80. -80. -80.]\n [-80. -...
# 1916  [[-80. -80. -80. ... -80. -80. -80.]\n [-80. -...
# 1917  [[-80. -80. -80. ... -80. -80. -80.]\n [-80. -...
# 1918  [[-80. -80. -80. ... -80. -80. -80.]\n [-80. -...
# 1919  [[-80. -80. -80. ... -80. -80. -80.]\n [-80. -...
#
#                                       spectral_centroid  \
# 480   [[  47.09266331   93.40151822  107.35733244  1...
# 481   [[ 202.50309528  190.23539599  187.02595113  2...
# 482   [[ 162.33896991  150.7499591    97.23343222  1...
# 483   [[ 454.92500759  206.36352228  173.57864395  1...
# 484   [[  73.46948286   62.39630099  108.36788402  1...
# ...                                                 ...
# 1915  [[  118.98885969   113.44669104   120.64340515...
# 1916  [[2818.7486401  1600.80020631 1190.07143714 11...
# 1917  [[ 229.76511242   98.89644275   96.59056637   ...
# 1918  [[  141.9615643     70.49711604    43.38773126...
# 1919  [[ 139.3577904    81.48380933   56.29249006   ...
#
#                                                    mfcc  \
# 480   [[3.63765685e-05 1.62419565e-05 1.21870935e-05...
# 481   [[6.3640209e-06 7.1016025e-06 5.9106369e-06 .....
# 482   [[9.18604565e-06 1.12763319e-05 1.91296058e-05...
# 483   [[1.2574272e-06 5.6115650e-06 9.4367679e-06 .....
# 484   [[2.6771961e-05 2.1848557e-05 1.2723341e-05 .....
# ...                                                 ...
# 1915  [[2.4975385e-05 2.8197735e-05 2.0353360e-05 .....
# 1916  [[7.3836891e-06 1.1596587e-05 2.1016045e-05 .....
# 1917  [[4.9638320e-06 3.0573374e-05 4.3237851e-05 .....
# 1918  [[8.1581247e-06 2.0380328e-05 4.3691849e-05 .....
# 1919  [[3.90835976e-06 1.13619044e-05 2.42971964e-05...
#
#                                             chroma_stft  \
# 480   [[0.6299272  0.54295194 0.8391381  ... 0.42764...
# 481   [[0.93197465 0.9680669  0.95783556 ... 0.89508...
# 482   [[1.         0.9445409  0.78295815 ... 0.71188...
# 483   [[1.         0.7509691  0.8913128  ... 1.     ...
# 484   [[0.8542507  0.90924865 0.953734   ... 1.     ...
# ...                                                 ...
# 1915  [[0.679909   0.7137233  0.8754716  ... 0.97773...
# 1916  [[0.2534683  0.29153574 0.275086   ... 0.77581...
# 1917  [[1.         0.9731513  0.84167665 ... 0.93534...
# 1918  [[1.         0.9454026  0.9370998  ... 0.99386...
# 1919  [[0.9914019  0.9920095  0.7737749  ... 1.     ...
#
#                                                 tonnetz    emotion  intensity  \
# 480   [[-3.43348352e-02 -3.32754906e-02 -3.64447257e...  surprised          2
# 481   [[-1.95297779e-02 -2.55960000e-02 -2.06846858e...    fearful          1
# 482   [[-0.19988226 -0.19554851 -0.19766569 ... -0.0...    disgust          1
# 483   [[-1.36104318e-01 -1.31217126e-01 -1.27951074e...  surprised          1
# 484   [[-4.60556426e-02 -4.31377894e-02 -4.28036590e...    disgust          2
# ...                                                 ...        ...        ...
# 1915  [[-0.12766553 -0.13068657 -0.13331536 ... -0.0...    disgust          1
# 1916  [[-0.08653583 -0.06998111 -0.06523895 ... -0.0...    fearful          2
# 1917  [[-4.62122075e-02 -4.71445367e-02 -5.42191662e...  surprised          1
# 1918  [[-5.99243943e-02 -5.70512783e-02 -6.08207860e...  surprised          1
# 1919  [[ 4.62745337e-02  4.21865715e-02  4.95622895e...    disgust          2
#
#       repetition actor_gender actor_age   source  Unnamed: 0
# 480            1         male         0  ravdess         0.0
# 481            2       female         0  ravdess         1.0
# 482            1         male         0  ravdess         2.0
# 483            2       female         0  ravdess         3.0
# 484            2       female         0  ravdess         4.0
# ...          ...          ...       ...      ...         ...
# 1915           1         male         0  ravdess      1435.0
# 1916           1         male         0  ravdess      1436.0
# 1917           2       female         0  ravdess      1437.0
# 1918           1         male         0  ravdess      1438.0
# 1919           1         male         0  ravdess      1439.0
#
# [1440 rows x 15 columns]

# %%
df_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1440 entries, 480 to 1919
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       1440 non-null   int64
#  1   id                 1440 non-null   object
#  2   wave               1440 non-null   object
#  3   spec               1440 non-null   object
#  4   spectral_centroid  1440 non-null   object
#  5   mfcc               1440 non-null   object
#  6   chroma_stft        1440 non-null   object
#  7   tonnetz            1440 non-null   object
#  8   emotion            1440 non-null   object
#  9   intensity          1440 non-null   int64
#  10  repetition         1440 non-null   int64
#  11  actor_gender       1440 non-null   object
#  12  actor_age          1440 non-null   object
#  13  source             1440 non-null   object
#  14  Unnamed: 0         1440 non-null   float64
# dtypes: float64(1), int64(3), object(11)
# memory usage: 180.0+ KB

# %%
import ast

# %%
df_short = df_short.reset_index().drop(columns=['index','Unnamed: 0'])

# %%
df_short.shape[0]
# Out:
# 1440

# %%
import re

# %%
tonnetz_5x = []
tonnetz_5y = []
tonnetz_3mx = []
tonnetz_3my = []
tonnetz_3Mx = []
tonnetz_3My = []
for row in np.arange(0, df_short.shape[0]):
      m_list = list(filter(None, re.split(" |\n|\[|\]", df_short["tonnetz"][row])))
      m_list[-1] = m_list[-1][:-1]
      m_list[0] = m_list[0][1:]
      b = int(len(m_list)/6)
      tonnetz_5x.append(m_list[:b])
      tonnetz_5y.append(m_list[b:b*2])
      tonnetz_3mx.append(m_list[b*2:b*3])
      tonnetz_3my.append(m_list[b*3:b*4])
      tonnetz_3Mx.append(m_list[b*4:b*5])
      tonnetz_3My.append(m_list[b*5:b*6])

# %%
mfcc_list = []
spec_list = []
wave_list = []
chroma_stft_list = []
spectral_centroid_list = []

for row in np.arange(0, df_short.shape[0]):
    m_list = list(filter(None, re.split(" |\n|\[|\]", df_short["mfcc"][row])))
    m_list[-1] = m_list[-1][:-1]
    m_list[0] = m_list[0][1:]
    mfcc_list.append(m_list)
for row in np.arange(0, df_short.shape[0]):
    m_list = list(filter(None, re.split(" |\n|\[|\]|", df_short["spec"][row])))
    m_list[-1] = m_list[-1][:-1]
    m_list[0] = m_list[0][1:]
    spec_list.append(m_list)
for row in np.arange(0, df_short.shape[0]):
    m_list = list(filter(None, re.split(" |\n|\[|\]", df_short["wave"][row])))
    m_list[-1] = m_list[-1][:-1]
    m_list[0] = m_list[0][1:]
    wave_list.append(m_list)
for row in np.arange(0, df_short.shape[0]):
    m_list = list(filter(None, re.split(" |\n|\[|\]", df_short["chroma_stft"][row])))
    m_list[-1] = m_list[-1][:-1]
    m_list[0] = m_list[0][1:]
    chroma_stft_list.append(m_list)
for row in np.arange(0, df_short.shape[0]):
    m_list = list(filter(None, re.split(" |\n|\[|\]", df_short["wave"][row])))
    m_list[-1] = m_list[-1][:-1]
    m_list[0] = m_list[0][1:]
    spectral_centroid_list.append(m_list)

# %%
tonnetz_5x = np.array([np.array(x) for x in tonnetz_5x])
tonnetz_5y = np.array([np.array(x) for x in tonnetz_5y])
tonnetz_3mx = np.array([np.array(x) for x in tonnetz_3mx])
tonnetz_3my = np.array([np.array(x) for x in tonnetz_3my])
tonnetz_3Mx = np.array([np.array(x) for x in tonnetz_3Mx])
tonnetz_3My = np.array([np.array(x) for x in tonnetz_3My])
mfcc_list = np.array([np.array(x) for x in mfcc_list])
spec_list = np.array([np.array(x) for x in spec_list])
wave_list = np.array([np.array(x) for x in wave_list])
chroma_stft_list = np.array([np.array(x) for x in chroma_stft_list])
spectral_centroid_list = np.array([np.array(x) for x in spectral_centroid_list])
# Out:
# /tmp/ipykernel_13506/4030802902.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_5x = np.array([np.array(x) for x in tonnetz_5x])
# /tmp/ipykernel_13506/4030802902.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_5y = np.array([np.array(x) for x in tonnetz_5y])
# /tmp/ipykernel_13506/4030802902.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_3mx = np.array([np.array(x) for x in tonnetz_3mx])
# /tmp/ipykernel_13506/4030802902.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_3my = np.array([np.array(x) for x in tonnetz_3my])
# /tmp/ipykernel_13506/4030802902.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_3Mx = np.array([np.array(x) for x in tonnetz_3Mx])
# /tmp/ipykernel_13506/4030802902.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_3My = np.array([np.array(x) for x in tonnetz_3My])
# /tmp/ipykernel_13506/4030802902.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   spec_list = np.array([np.array(x) for x in spec_list])

# %%
# tonnetz_5x = np.array([np.array(x) for x in tonnetz_5x])
# tonnetz_5y = np.array([np.array(x) for x in tonnetz_5y])
# tonnetz_3mx = np.array([np.array(x) for x in tonnetz_3mx])
# tonnetz_3my = np.array([np.array(x) for x in tonnetz_3my])
# tonnetz_3Mx = np.array([np.array(x) for x in tonnetz_3Mx])
# tonnetz_3My = np.array([np.array(x) for x in tonnetz_3My])
# mfcc_list = np.array([np.array(x) for x in mfcc_list])
# spec_list = np.array([np.array(x) for x in spec_list])
# wave_list = np.array([np.array(x) for x in wave_list])
# chroma_stft_list = np.array([np.array(x) for x in chroma_stft_list])
# spectral_centroid_list = np.array([np.array(x) for x in spectral_centroid_list])

# %%
remove = ['...', '.']

# %%
tonnetz_5x = np.array([np.setdiff1d(x,remove) for x in tonnetz_5x])
tonnetz_5y = np.array([np.setdiff1d(x,remove)for x in tonnetz_5y])
tonnetz_3mx = np.array([np.setdiff1d(x,remove) for x in tonnetz_3mx])
tonnetz_3my = np.array([np.setdiff1d(x,remove) for x in tonnetz_3my])
tonnetz_3Mx = np.array([np.setdiff1d(x,remove) for x in tonnetz_3Mx])
tonnetz_3My = np.array([np.setdiff1d(x,remove) for x in tonnetz_3My])
mfcc_list = np.array([np.setdiff1d(x,remove) for x in mfcc_list])
spec_list = np.array([np.setdiff1d(x,remove) for x in spec_list])
wave_list = np.array([np.setdiff1d(x,remove) for x in wave_list])
chroma_stft_list = np.array([np.setdiff1d(x,remove) for x in chroma_stft_list])
spectral_centroid_list = np.array([np.setdiff1d(x,remove) for x in spectral_centroid_list])
# Out:
# /tmp/ipykernel_13506/3270696936.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_5x = np.array([np.setdiff1d(x,remove) for x in tonnetz_5x])
# /tmp/ipykernel_13506/3270696936.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_5y = np.array([np.setdiff1d(x,remove)for x in tonnetz_5y])
# /tmp/ipykernel_13506/3270696936.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_3mx = np.array([np.setdiff1d(x,remove) for x in tonnetz_3mx])
# /tmp/ipykernel_13506/3270696936.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_3my = np.array([np.setdiff1d(x,remove) for x in tonnetz_3my])
# /tmp/ipykernel_13506/3270696936.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_3Mx = np.array([np.setdiff1d(x,remove) for x in tonnetz_3Mx])
# /tmp/ipykernel_13506/3270696936.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tonnetz_3My = np.array([np.setdiff1d(x,remove) for x in tonnetz_3My])
# /tmp/ipykernel_13506/3270696936.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mfcc_list = np.array([np.setdiff1d(x,remove) for x in mfcc_list])
# /tmp/ipykernel_13506/3270696936.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   spec_list = np.array([np.setdiff1d(x,remove) for x in spec_list])
# /tmp/ipykernel_13506/3270696936.py:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   wave_list = np.array([np.setdiff1d(x,remove) for x in wave_list])
# /tmp/ipykernel_13506/3270696936.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   chroma_stft_list = np.array([np.setdiff1d(x,remove) for x in chroma_stft_list])
# /tmp/ipykernel_13506/3270696936.py:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   spectral_centroid_list = np.array([np.setdiff1d(x,remove) for x in spectral_centroid_list])

# %%
spectral_centroid_list[0][0]
# Out:
# '-1.14064045e-04'

# %%
tonnetz_3My[0] = tonnetz_3My[0].astype('float64')

# %%
features = [tonnetz_5x, tonnetz_5y, tonnetz_3mx,tonnetz_3my, tonnetz_3Mx,tonnetz_3My,spectral_centroid_list,chroma_stft_list,wave_list,wave_list,mfcc_list]

# %%
dic = {'tonnetz_5x':tonnetz_5x,'tonnetz_5y':tonnetz_5y,'tonnetz_3mx':tonnetz_3mx,
        'tonnetz_3my':tonnetz_3my,'tonnetz_3Mx':tonnetz_3Mx,'tonnetz_3My':tonnetz_3My,
        'spectral_centroid':spectral_centroid_list,'chroma_stft':chroma_stft_list,'wave':wave_list,
        'spec':spec_list,'mfcc':mfcc_list}

# %%
lengg = []
for i in :
  lengg.append(len(i))

# %%
result = []
for i, leng in enumerate(lengg):
        temp = []
        for j in range(leng):
            temp.append(np.stack((tonnetz_5x[i][j],tonnetz_5y[i][j],tonnetz_3mx[i][j],
                      tonnetz_3my[i][j],tonnetz_3Mx[i][j],tonnetz_3My[i][j])))
        result.append(temp)

# %%
result = np.array([np.array(x) for x in result])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Pad the training and test embedded sentences
X= pad_sequences(result, dtype='float64', padding='post', maxlen=166)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils, to_categorical

# %%
lb = LabelEncoder()

# %%
y_cat = np_utils.to_categorical(lb.fit_transform(y))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_cat, test_size=0.30, random_state=1405, stratify=y)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# %%
model = models.Sequential()
model.add(layers.Masking(mask_value=0))
model.add(layers.Conv1D(256, 8, padding="same", activation = "tanh"))
model.add(layers.Conv1D(256, 8, padding='same', activation = "tanh"))
# model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.25))
model.add(layers.MaxPooling1D(pool_size=(8)))
model.add(layers.Conv1D(128, 8, padding='same', activation = "tanh"))
model.add(layers.Conv1D(128, 8, padding='same', activation = "tanh"))
model.add(layers.Conv1D(128, 8, padding='same', activation = "tanh"))
model.add(layers.Conv1D(128, 8, padding='same', activation = "tanh"))
# model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.25))
model.add(layers.MaxPooling1D(pool_size=(8)))
model.add(layers.Conv1D(64, 8, padding='same', activation = "tanh"))
model.add(layers.Conv1D(64, 8, padding='same', activation = "tanh"))
model.add(layers.Flatten())
model.add(layers.Dense(32, activation = "relu"))
model.add(layers.Dense(64, activation = "relu"))
model.add(layers.Dense(8, activation = "softmax"))
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy", "recall"])

# %%
es = EarlyStopping(patience=10, restore_best_weights=True)
model.fit(X_train, y_train, validation_split=0.3, epochs=500, batch_size=32, callbacks=[es])
