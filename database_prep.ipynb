# %%
from audio_formating import silvertone

# %%
test_1 = silvertone("/content/03-01-01-01-01-01-01.wav", 256)

# %%
test_1.plot_mel_spec((10,5))

# %%
test_1.S_db_mel
# Out:
# array([[-80., -80., -80., ..., -80., -80., -80.],
#        [-80., -80., -80., ..., -80., -80., -80.],
#        [-80., -80., -80., ..., -80., -80., -80.],
#        ...,
#        [-80., -80., -80., ..., -80., -80., -80.],
#        [-80., -80., -80., ..., -80., -80., -80.],
#        [-80., -80., -80., ..., -80., -80., -80.]], dtype=float32)

# %%
test_1.S_db_mel.shape
# Out:
# (256, 143)

# %%
test_1.y
# Out:
# array([ 1.6517616e-08, -6.5464434e-08,  1.2522355e-07, ...,
#         0.0000000e+00,  0.0000000e+00,  0.0000000e+00], dtype=float32)

# %%
test_1.sr
# Out:
# 22050

# %%
from glob import glob
from google.colab import drive
import numpy as np

# %%
speech = glob("/content/drive/MyDrive/Audio/RAVDESS/Audio_Speech_Actors_01-24/*.wav")

# %%
speech[0][-24:-4]
# Out:
# '03-01-02-01-02-02-01'

# %%
wave = []
id = []
for tone in np.arange(0, len(speech)):
  tone = silvertone(speech[tone], 256)
  wave.append(tone.S_db_mel)
  id.append(speech[0][-24:-4])

# %%
dic = {"wave": wave, "id": id}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#                                                   wave                    id
# 0    [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# 1    [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# 2    [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# 3    [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# 4    [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# ..                                                 ...                   ...
# 325  [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# 326  [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# 327  [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# 328  [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
# 329  [[-80.0, -80.0, -80.0, -80.0, -80.0, -80.0, -8...  03-01-02-01-02-02-01
#
# [330 rows x 2 columns]
